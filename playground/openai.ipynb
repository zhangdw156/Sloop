# %%
from openai import OpenAI
import httpx
import rich
from rich.markdown import Markdown
from rich.json import JSON

# %%
messages = [
    {"role":"user","content":"北京的和上海的天气怎么样？"}
]

# %%
tools = [{
        "type": "function",
        "function": {
            "name": "get_weather",
            "description": "Get the current weather in a given location",
            "parameters": {
                "type": "object",
                "properties": {
                    "location": {"type": "string", "description": "City and state, e.g., 'San Francisco, CA'"},
                    "unit": {"type": "string", "enum": ["celsius", "fahrenheit"]}
                },
                "required": ["location", "unit"]
            }
        }
    }]

# %% [markdown]
# ## 稳定的235ba22b

# %%
base_url = "http://103.212.13.119:8000/v1/"
model_name = "Qwen3-235B-A22B-Instruct-2507"
api_key = "qwertiasagv"

# %%
client = OpenAI(
    base_url=base_url,
    api_key=api_key,
    http_client=httpx.Client(verify=False)
)

# %%
result = client.chat.completions.create(
        model=model_name,
        messages=messages,
        # tools=tools,
        stream=False,
        extra_body={
            "chat_template_kwargs": {"enable_thinking": True, "thinking": True},
        },
        temperature=0.7,
        max_completion_tokens=2048
    )
rich.print(result)
# Out:
# ChatCompletion(
#     id='chatcmpl-8cd4eff01d7309f8',
#     choices=[
#         Choice(
#             finish_reason='stop',
#             index=0,
#             logprobs=None,
#             message=ChatCompletionMessage(
#                 content='截至我知识截止时间（2024年6月），我无法提供实时天气信息。建议您通过权威气象网站或应用（如
# 中国气象局官网、中央气象台、天气通、墨迹天气或手机自带天气应用）查询北京和上海的最新天气情况。\n\n不过，我可以为您
# 简要介绍两地的气候特点：\n\n🔹 北京：\n- 属于温带季风气候，四季分明。\n- 春季干燥多风，气温变化大。\n-
# 夏季炎热多雨，7月最热，平均气温约26°C。\n- 秋季凉爽宜人，是最佳旅游季节。\n-
# 冬季寒冷干燥，1月最冷，平均气温约-4°C至4°C，偶有降雪。\n\n🔹 上海：\n- 属于亚热带季风气候，温和湿润。\n-
# 春季回暖较早，多阴雨。\n- 夏季炎热潮湿，6-7月为梅雨季，7-8月高温可达35°C以上。\n- 秋季短暂但舒适。\n-
# 冬季湿冷，1月最冷，平均气温约3°C至8°C，少雪。\n\n如需当前天气，请开启联网功能或使用天气应用获取实时数据。',
#                 refusal=None,
#                 role='assistant',
#                 annotations=None,
#                 audio=None,
#                 function_call=None,
#                 tool_calls=[],
#                 reasoning=None,
#                 reasoning_content=None
#             ),
#             stop_reason=None,
#             token_ids=None
#         )
#     ],
#     created=1768208278,
#     model='Qwen3-235B-A22B-Instruct-2507',
#     object='chat.completion',
#     service_tier=None,
#     system_fingerprint=None,
#     usage=CompletionUsage(
#         completion_tokens=270,
#         prompt_tokens=16,
#         total_tokens=286,
#         completion_tokens_details=None,
#         prompt_tokens_details=None
#     ),
#     prompt_logprobs=None,
#     prompt_token_ids=None,
#     kv_transfer_params=None
# )

# %%
result = client.chat.completions.create(
        model=model_name,
        messages=messages,
        # tools=tools,
        stream=False,
        extra_body={
            "chat_template_kwargs": {"enable_thinking": True, "thinking": True},
        },
        temperature=0.7,
        max_completion_tokens=2048
    )
rich.print(Markdown(result.choices[0].message.content))
# Out:
# 截至我知识截止的时间（2024年6月），以下是北京和上海天气的一般情况（请注意，具体天气会随季节和实时变化而有所不同，建
# 议查看最新的天气预报获取准确信息）：
#
# 北京天气概况：
#
#  • 北京属于温带季风气候，四季分明。
#  • 春季（3月-5月）：干燥多风，气温逐渐回升，偶有沙尘天气。
#  • 夏季（6月-8月）：炎热多雨，7月最热，平均气温约25-30°C，常有雷阵雨。
#  • 秋季（9月-11月）：秋高气爽，气温适宜，是最佳旅游季节。
#  • 冬季（12月-2月）：寒冷干燥，常有北风，平均气温在0°C以下，偶有降雪。
#
# 上海天气概况：
#
#  • 上海属于亚热带季风气候，温和湿润，四季分明。
#  • 春季：温暖湿润，偶有阴雨。
#  • 夏季：炎热潮湿，6月至9月为梅雨季和高温期，气温常达30-35°C，有时有台风影响。
#  • 秋季：凉爽宜人，降水减少，气候舒适。
#  • 冬季：湿冷，气温通常在0-10°C之间，虽少降雪，但体感寒冷。
#
# 温馨提示：
# 如需了解当前实时天气，请使用天气应用或访问中国气象局、中央气象台等权威网站查询北京和上海的最新天气预报。

# %%
result = client.chat.completions.create(
        model=model_name,
        messages=messages,
        tools=tools,
        stream=False,
        extra_body={
            "chat_template_kwargs": {"enable_thinking": True, "thinking": True},
        },
        temperature=0.7,
        max_completion_tokens=2048
    )
for too_call in result.choices[0].message.tool_calls:
    rich.print(too_call)
# Out:
# ChatCompletionMessageFunctionToolCall(
#     id='chatcmpl-tool-92fa22cf84b300a5',
#     function=Function(arguments='{"location": "北京, 中国", "unit": "celsius"}', name='get_weather'),
#     type='function'
# )
# ChatCompletionMessageFunctionToolCall(
#     id='chatcmpl-tool-a7560f34013bb220',
#     function=Function(arguments='{"location": "上海, 中国", "unit": "celsius"}', name='get_weather'),
#     type='function'
# )

# %% [markdown]
# ## 临时的8b

# %%
base_url = "http://10.254.117.65:8443/service-large-1045-1766758890786/llm/v1"
model_name = "qwen3-8b-baseline"
api_key = "KJLBQJc7jnwl86jl67r687187mAQcsBvrr8gpArw0rmR74tqlzZHtS9sc76kqdvGJ8pkwS0wc64dSWPv0mVx87mVr7F74k4N6m7THFWqrzzmB5KnjD997p8CS7t064X7"

# %%
client = OpenAI(
    base_url=base_url,
    api_key=api_key,
    http_client=httpx.Client(verify=False)
)

# %%
result = client.chat.completions.create(
        model=model_name,
        messages=messages,
        tools=tools,
        stream=False,
        extra_body={
            "chat_template_kwargs": {"enable_thinking": False, "thinking": False},
        },
        temperature=0.7,
        max_completion_tokens=4096
    )
# rich.print(Markdown(result.choices[0].message.content))
rich.print(result)
# Out:
# ChatCompletion(
#     id='chatcmpl-9c4992eaeb77405d837cfbb78ee25337',
#     choices=[
#         Choice(
#             finish_reason='tool_calls',
#             index=0,
#             logprobs=None,
#             message=ChatCompletionMessage(
#                 content=None,
#                 refusal=None,
#                 role='assistant',
#                 annotations=None,
#                 audio=None,
#                 function_call=None,
#                 tool_calls=[
#                     ChatCompletionMessageFunctionToolCall(
#                         id='chatcmpl-tool-ea551da94c774fc18646dc35c477b086',
#                         function=Function(
#                             arguments='{"location": "北京", "unit": "celsius"}',
#                             name='get_weather'
#                         ),
#                         type='function'
#                     ),
#                     ChatCompletionMessageFunctionToolCall(
#                         id='chatcmpl-tool-e30de68354d64716a402519971041d71',
#                         function=Function(
#                             arguments='{"location": "上海", "unit": "celsius"}',
#                             name='get_weather'
#                         ),
#                         type='function'
#                     )
#                 ],
#                 reasoning_content=None
#             ),
#             stop_reason=None
#         )
#     ],
#     created=1768210250,
#     model='qwen3-8b-baseline',
#     object='chat.completion',
#     service_tier=None,
#     system_fingerprint=None,
#     usage=CompletionUsage(
#         completion_tokens=54,
#         prompt_tokens=200,
#         total_tokens=254,
#         completion_tokens_details=None,
#         prompt_tokens_details=None
#     ),
#     prompt_logprobs=None,
#     kv_transfer_params=None
# )
